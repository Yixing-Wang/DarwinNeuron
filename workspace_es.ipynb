# %%
import wandb
import torch, wandb, os
import torch.optim as optim
from torch.nn.functional import cross_entropy
from functools import partial

from src.RandmanFunctions import RandmanConfig, split_and_load
from src.Models import RandmanSNN, spike_regularized_cross_entropy
from src.EvolutionAlgorithms.EvolutionStrategy import ESModel
from src.EvolutionAlgorithms.PseudoPSO import PPSOModel, PPSOModelWithPooling
from src.SurrogateGD.VanillaSGD import SGDModel
from src.Training import train_loop_snn
from src.Utilities import init_result_csv, set_seed
from src.LandscapeAnalysis.LossSurfacePlotter import LossSurfacePlotter

device = 'cuda'
loss_fn_spk = lambda logits, y, spikes: spike_regularized_cross_entropy(logits, y, spikes, lambda_reg=1e-3)

@torch.no_grad()
def train_snn():
    run_name = "es"
    config = {  # Dataset:
        "nb_input": 10,
        "nb_output": 10,
        "nb_steps": 50,
        "nb_data_samples": 1000,
        "dim_manifold": 2,
        "alpha": 2.0,
        # SNN:
        "nb_hidden": 100,
        "learn_beta": False,
        # Evolution Strategy:
        "nb_model_samples": 100,
        "mirror": True,
        # Training:
        "std": 0.1,
        "epochs": 5,
        "batch_size": 256,
        "method": "es",
        # Optimization:
        "loss": "loss_fn",
        "optimizer": "Adam",
        "lr": 0.01,
        "regularization": "none",
    }
    with wandb.init(
        entity="DarwinNeuron", project="big-sweep-test", name=run_name, config=config
    ) as run:
        # update current run_name
        keys = ["method", "std", "batch_size", "lr", "nb_model_samples", "loss", "nb_input"]
        sorted_items = [f"{getattr(run.config, k)}" for k in sorted(keys)]
        run.name = "-".join(sorted_items)
        
        # setting up local csv recording (optional)
        result_path, _, _ = init_result_csv(dict(run.config), run.project)

        my_model = ESModel(
            RandmanSNN,
            run.config.nb_input,
            run.config.nb_hidden,
            run.config.nb_output,
            run.config.learn_beta, 
            sample_size=run.config.nb_model_samples,
            param_std=run.config.std,
            Optimizer=optim.Adam,
            lr=run.config.lr,
            device=device,
            mirror=run.config.mirror,
        )

        # load dataset
        train_loader, val_loader = split_and_load(
            RandmanConfig(
                nb_classes=run.config.nb_output,
                nb_units=run.config.nb_input,
                nb_steps=run.config.nb_steps,
                nb_samples=run.config.nb_data_samples,
                dim_manifold=run.config.dim_manifold,
                alpha=run.config.alpha,
            ).read_dataset(),
            run.config.batch_size,
        )
        
        # loss surface plotter
        plotter_dir = f"results/{run.project}/runs/{run.id}/"
        os.makedirs(plotter_dir, exist_ok=True)
        loss_plotter = LossSurfacePlotter(plotter_dir+"illuminated_loss_surface.npz")

        # epochs
        for epoch in range(run.config.epochs):
            print(f"Epoch {epoch}\n-------------------------------")

            # train the model
            train_loop_snn(my_model, train_loader, val_loader, loss_fn_spk, device, run, epoch, loss_plotter=None)

train_snn()
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/scratch/wx2178/wandb_local/wandb/run-20250802_144218-cex11x6a</code>
# Syncing run <strong><a href='https://wandb.ai/DarwinNeuron/big-sweep-test/runs/cex11x6a' target="_blank">es</a></strong> to <a href='https://wandb.ai/DarwinNeuron/big-sweep-test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/DarwinNeuron/big-sweep-test' target="_blank">https://wandb.ai/DarwinNeuron/big-sweep-test</a>
#  View run at <a href='https://wandb.ai/DarwinNeuron/big-sweep-test/runs/cex11x6a' target="_blank">https://wandb.ai/DarwinNeuron/big-sweep-test/runs/cex11x6a</a>
# Epoch 0
# -------------------------------
# batch 0, loss: 2.300166, accuracy: 10.5%
# Accuracy: 10.7%, Avg loss: 2.301792
#
# batch 1, loss: 2.301507, accuracy: 9.8%
# Accuracy: 10.3%, Avg loss: 2.302051
#
# batch 2, loss: 2.302517, accuracy: 9.4%
# Accuracy: 10.4%, Avg loss: 2.301648
#
# batch 3, loss: 2.298573, accuracy: 12.9%
# Accuracy: 10.5%, Avg loss: 2.301483
#
# batch 4, loss: 2.302034, accuracy: 12.5%
# Accuracy: 10.4%, Avg loss: 2.301721
#
# batch 5, loss: 2.299236, accuracy: 9.8%
# Accuracy: 10.5%, Avg loss: 2.301780
#
# batch 6, loss: 2.300574, accuracy: 11.3%
# Accuracy: 10.5%, Avg loss: 2.301749
#
# batch 7, loss: 2.302858, accuracy: 8.6%
# Accuracy: 10.5%, Avg loss: 2.301686
#
# batch 8, loss: 2.301569, accuracy: 10.9%
# Accuracy: 10.7%, Avg loss: 2.301609
#
# batch 9, loss: 2.302341, accuracy: 9.0%
# Accuracy: 10.7%, Avg loss: 2.301648
#
# batch 10, loss: 2.301835, accuracy: 9.8%
# Accuracy: 10.7%, Avg loss: 2.301631
#
# batch 11, loss: 2.301969, accuracy: 13.3%
# Accuracy: 10.7%, Avg loss: 2.301694
#
# batch 12, loss: 2.302572, accuracy: 10.5%
# Accuracy: 10.7%, Avg loss: 2.301773
#
# batch 13, loss: 2.302372, accuracy: 9.0%
# Accuracy: 10.7%, Avg loss: 2.301522
#
# batch 14, loss: 2.301232, accuracy: 13.7%
# Accuracy: 10.7%, Avg loss: 2.301528
#
# batch 15, loss: 2.302015, accuracy: 12.1%
# Accuracy: 10.8%, Avg loss: 2.301060
#
# batch 16, loss: 2.298506, accuracy: 8.6%
# Accuracy: 10.8%, Avg loss: 2.300558
#
# batch 17, loss: 2.300393, accuracy: 7.4%
# Accuracy: 11.0%, Avg loss: 2.299742
#
# batch 18, loss: 2.299090, accuracy: 10.9%
# Accuracy: 11.0%, Avg loss: 2.299381
#
# batch 19, loss: 2.300324, accuracy: 9.8%
# Accuracy: 11.5%, Avg loss: 2.298052
#
# batch 20, loss: 2.299263, accuracy: 14.5%
# Accuracy: 11.5%, Avg loss: 2.297532
#
# batch 21, loss: 2.294345, accuracy: 9.4%
# Accuracy: 11.5%, Avg loss: 2.296532
#
# batch 22, loss: 2.295998, accuracy: 12.5%
# Accuracy: 12.2%, Avg loss: 2.294862
#
# batch 23, loss: 2.296750, accuracy: 14.3%
# Accuracy: 12.7%, Avg loss: 2.293741
#
# Epoch 1
# -------------------------------
# batch 0, loss: 2.294736, accuracy: 10.5%
# Accuracy: 12.8%, Avg loss: 2.292380
#
# batch 1, loss: 2.291655, accuracy: 14.5%
# Accuracy: 13.1%, Avg loss: 2.291528
#
# batch 2, loss: 2.297577, accuracy: 12.5%
# Accuracy: 13.5%, Avg loss: 2.290111
#
# batch 3, loss: 2.287986, accuracy: 14.1%
# Accuracy: 13.6%, Avg loss: 2.289279
#
# batch 4, loss: 2.291735, accuracy: 12.5%
# Accuracy: 13.8%, Avg loss: 2.289011
#
# batch 5, loss: 2.286095, accuracy: 16.4%
# Accuracy: 13.8%, Avg loss: 2.288768
#
# batch 6, loss: 2.287182, accuracy: 14.8%
# Accuracy: 14.1%, Avg loss: 2.288365
#
# batch 7, loss: 2.283004, accuracy: 15.2%
# Accuracy: 14.3%, Avg loss: 2.286907
#
# batch 8, loss: 2.290484, accuracy: 14.1%
# Accuracy: 14.8%, Avg loss: 2.285460
#
# batch 9, loss: 2.285394, accuracy: 14.5%
# Accuracy: 14.7%, Avg loss: 2.284084
#
# batch 10, loss: 2.282691, accuracy: 16.4%
# Accuracy: 15.1%, Avg loss: 2.282593
#
# batch 11, loss: 2.271786, accuracy: 21.1%
# Accuracy: 15.4%, Avg loss: 2.281200
#
# batch 12, loss: 2.282350, accuracy: 11.7%
# Accuracy: 16.2%, Avg loss: 2.280102
#
# batch 13, loss: 2.268028, accuracy: 18.8%
# Accuracy: 16.7%, Avg loss: 2.278540
#
# batch 14, loss: 2.273834, accuracy: 17.6%
# Accuracy: 16.8%, Avg loss: 2.278486
#
# batch 15, loss: 2.285606, accuracy: 17.6%
# Accuracy: 16.8%, Avg loss: 2.277908
#
# batch 16, loss: 2.268104, accuracy: 19.5%
# Accuracy: 17.1%, Avg loss: 2.276925
#
# batch 17, loss: 2.280803, accuracy: 15.6%
# Accuracy: 17.3%, Avg loss: 2.275717
#
# batch 18, loss: 2.268972, accuracy: 23.0%
# Accuracy: 17.9%, Avg loss: 2.273957
#
# batch 19, loss: 2.252140, accuracy: 18.8%
# Accuracy: 18.4%, Avg loss: 2.272258
#
# batch 20, loss: 2.275732, accuracy: 14.5%
# Accuracy: 18.6%, Avg loss: 2.269795
#
# batch 21, loss: 2.279184, accuracy: 16.4%
# Accuracy: 19.1%, Avg loss: 2.266391
#
# batch 22, loss: 2.270366, accuracy: 19.5%
# Accuracy: 19.6%, Avg loss: 2.263772
#
# batch 23, loss: 2.274533, accuracy: 17.0%
# Accuracy: 20.2%, Avg loss: 2.261765
#
# Epoch 2
# -------------------------------
# batch 0, loss: 2.258610, accuracy: 21.1%
# Accuracy: 20.5%, Avg loss: 2.260505
#
# batch 1, loss: 2.270445, accuracy: 19.9%
# Accuracy: 21.1%, Avg loss: 2.259077
#
# batch 2, loss: 2.257329, accuracy: 20.3%
# Accuracy: 21.4%, Avg loss: 2.258239
#
# batch 3, loss: 2.270747, accuracy: 22.3%
# Accuracy: 21.8%, Avg loss: 2.257981
#
# batch 4, loss: 2.257852, accuracy: 19.5%
# Accuracy: 21.4%, Avg loss: 2.257715
#
# batch 5, loss: 2.268128, accuracy: 18.4%
# Accuracy: 21.3%, Avg loss: 2.258628
#
# batch 6, loss: 2.259897, accuracy: 23.4%
# Accuracy: 21.7%, Avg loss: 2.258231
#
# batch 7, loss: 2.257586, accuracy: 23.4%
# Accuracy: 21.8%, Avg loss: 2.257930
#
# batch 8, loss: 2.254815, accuracy: 21.9%
# Accuracy: 21.9%, Avg loss: 2.256926
#
# batch 9, loss: 2.248238, accuracy: 19.5%
# Accuracy: 21.9%, Avg loss: 2.255603
#
# batch 10, loss: 2.252098, accuracy: 22.3%
# Accuracy: 21.7%, Avg loss: 2.253575
#
# batch 11, loss: 2.242774, accuracy: 21.5%
# Accuracy: 22.2%, Avg loss: 2.251848
#
# batch 12, loss: 2.248940, accuracy: 23.4%
# Accuracy: 22.4%, Avg loss: 2.249222
#
# batch 13, loss: 2.245094, accuracy: 21.5%
# Accuracy: 22.4%, Avg loss: 2.245141
#
# batch 14, loss: 2.249674, accuracy: 18.4%
# Accuracy: 21.9%, Avg loss: 2.242070
#
# batch 15, loss: 2.243272, accuracy: 21.1%
# Accuracy: 22.2%, Avg loss: 2.238214
#
# batch 16, loss: 2.256469, accuracy: 19.1%
# Accuracy: 22.1%, Avg loss: 2.235149
#
# batch 17, loss: 2.247773, accuracy: 18.4%
# Accuracy: 21.9%, Avg loss: 2.233852
#
# batch 18, loss: 2.227021, accuracy: 22.3%
# Accuracy: 22.2%, Avg loss: 2.230934
#
# batch 19, loss: 2.226027, accuracy: 20.7%
# Accuracy: 21.6%, Avg loss: 2.230395
#
# batch 20, loss: 2.233817, accuracy: 19.5%
# Accuracy: 21.6%, Avg loss: 2.229127
#
# batch 21, loss: 2.248366, accuracy: 21.5%
# Accuracy: 21.8%, Avg loss: 2.226892
#
# batch 22, loss: 2.232503, accuracy: 18.4%
# Accuracy: 21.9%, Avg loss: 2.226446
#
# batch 23, loss: 2.201691, accuracy: 20.5%
# Accuracy: 22.1%, Avg loss: 2.224347
#
# Epoch 3
# -------------------------------
# batch 0, loss: 2.228365, accuracy: 21.1%
# Accuracy: 22.4%, Avg loss: 2.222292
#
# batch 1, loss: 2.203960, accuracy: 24.6%
# Accuracy: 22.2%, Avg loss: 2.220736
#
# batch 2, loss: 2.204775, accuracy: 24.2%
# Accuracy: 22.5%, Avg loss: 2.217465
#
# batch 3, loss: 2.220016, accuracy: 18.4%
# Accuracy: 22.7%, Avg loss: 2.215721
#
# batch 4, loss: 2.194554, accuracy: 23.8%
# Accuracy: 23.1%, Avg loss: 2.213720
