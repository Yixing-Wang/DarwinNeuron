# %%
import wandb
import torch, wandb, os
import torch.optim as optim
from torch.nn.functional import cross_entropy
from functools import partial

from src.RandmanFunctions import RandmanConfig, split_and_load
from src.Models import RandmanSNN, spike_regularized_cross_entropy
from src.EvolutionAlgorithms.EvolutionStrategy import ESModel
from src.EvolutionAlgorithms.PseudoPSO import PPSOModel, PPSOModelWithPooling
from src.SurrogateGD.VanillaSGD import SGDModel
from src.Training import train_loop_snn
from src.Utilities import init_result_csv, set_seed
# from src.LandscapeAnalysis import LossSurfacePlotter
from src.LandscapeAnalysis.LossSurfacePlotter import LossSurfacePlotter

device = 'cuda'
loss_fn_spk = lambda logits, y, spikes: spike_regularized_cross_entropy(logits, y, spikes, lambda_reg=1e-3)

# @torch.no_grad()
def train_snn():
    run_name = "SGD-test"
    config = {  # Dataset:
        "nb_input": 10,
        "nb_output": 10,
        "nb_steps": 50,
        "nb_data_samples": 1000,
        "dim_manifold": 2,
        "alpha": 2.0,
        # SNN:
        "nb_hidden": 100,
        "learn_beta": False,
        "recurrent": False,
        # Evolution Strategy:
        "nb_model_samples": 100,
        "mirror": True,
        # Training:
        "std": 0.1,
        "epochs": 5,
        "batch_size": 256,
        "method": "SGD",
        # Optimization:
        "loss": "loss_fn_spk", #loss_fn_spk
        "optimizer": "Adam",
        "lr": 0.01,
        "regularization": "none",
    }
    with wandb.init(
        entity="DarwinNeuron", project="Test", name=run_name, config=config
    ) as run:
        # update current run_name
        keys = ["method", "std", "batch_size", "lr", "nb_model_samples", "loss","nb_input"]
        sorted_items = [f"{getattr(run.config, k)}" for k in sorted(keys)]
        run.name = "-".join(sorted_items)
        
        # setting up local csv recording (optional)
        result_path, _, _ = init_result_csv(dict(run.config), run.project)

        # initialize Evolution Strategy instance
        my_model = SGDModel(
                RandmanSNN,
                run.config.nb_input,
                run.config.nb_hidden,
                run.config.nb_output,
                run.config.learn_beta,
                spike_grad=None,   # ← default surrogate gradient
                recurrent=run.config.recurrent,
                Optimizer=optim.Adam,
                lr=run.config.lr,
                device=device,
            )

        # load dataset
        train_loader, val_loader = split_and_load(
            RandmanConfig(
                nb_classes=run.config.nb_output,
                nb_units=run.config.nb_input,
                nb_steps=run.config.nb_steps,
                nb_samples=run.config.nb_data_samples,
                dim_manifold=run.config.dim_manifold,
                alpha=run.config.alpha,
            ).read_dataset(),
            run.config.batch_size,
        )
        
        # loss surface plotter
        plotter_dir = f"results/{run.project}/runs/{run.id}/"
        os.makedirs(plotter_dir, exist_ok=True)
        loss_plotter = LossSurfacePlotter(plotter_dir+"illuminated_loss_surface.npz")

        # epochs
        for epoch in range(run.config.epochs):
            print(f"Epoch {epoch}\n-------------------------------")

            # train the model
            train_loop_snn(my_model, train_loader, val_loader, loss_fn_spk, device, run, epoch, loss_plotter=None)

train_snn()
# Out:
# wandb: Currently logged in as: yixing to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>c:\Users\w1886\OneDrive\Documents\GitHub\DarwinNeuron\wandb\run-20250813_164437-k61yczh9</code>
# Syncing run <strong><a href='https://wandb.ai/DarwinNeuron/Test/runs/k61yczh9' target="_blank">SGD-test</a></strong> to <a href='https://wandb.ai/DarwinNeuron/Test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/DarwinNeuron/Test' target="_blank">https://wandb.ai/DarwinNeuron/Test</a>
#  View run at <a href='https://wandb.ai/DarwinNeuron/Test/runs/k61yczh9' target="_blank">https://wandb.ai/DarwinNeuron/Test/runs/k61yczh9</a>
# filepath data/randman\a818832ebb0748ed8125b520de22a658.pt
# Epoch 0
# -------------------------------
# batch 0, loss: 2.302585, accuracy: 10.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 1, loss: 2.302585, accuracy: 7.0%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 2, loss: 2.302585, accuracy: 12.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 3, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 4, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 5, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 6, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 7, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 8, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 9, loss: 2.302585, accuracy: 12.1%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 10, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 11, loss: 2.302585, accuracy: 7.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 12, loss: 2.302585, accuracy: 12.9%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 13, loss: 2.302585, accuracy: 10.9%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 14, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 15, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 16, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 17, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 18, loss: 2.302585, accuracy: 10.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 19, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 20, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 21, loss: 2.302585, accuracy: 12.1%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 22, loss: 2.302585, accuracy: 9.0%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 23, loss: 2.302586, accuracy: 7.1%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# Epoch 1
# -------------------------------
# batch 0, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 1, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 2, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 3, loss: 2.302585, accuracy: 8.6%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 4, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 5, loss: 2.302585, accuracy: 10.9%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 6, loss: 2.302585, accuracy: 6.6%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 7, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 8, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 9, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 10, loss: 2.302585, accuracy: 10.9%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 11, loss: 2.302585, accuracy: 10.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 12, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 13, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 14, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 15, loss: 2.302585, accuracy: 8.6%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 16, loss: 2.302585, accuracy: 12.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 17, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 18, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 19, loss: 2.302585, accuracy: 13.7%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 20, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 21, loss: 2.302585, accuracy: 12.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 22, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 23, loss: 2.302586, accuracy: 8.0%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# Epoch 2
# -------------------------------
# batch 0, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 1, loss: 2.302585, accuracy: 10.9%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 2, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 3, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 4, loss: 2.302585, accuracy: 14.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 5, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 6, loss: 2.302585, accuracy: 7.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 7, loss: 2.302585, accuracy: 9.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 8, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 9, loss: 2.302585, accuracy: 7.4%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 10, loss: 2.302585, accuracy: 13.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 11, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 12, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 13, loss: 2.302585, accuracy: 12.1%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 14, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 15, loss: 2.302585, accuracy: 9.8%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 16, loss: 2.302585, accuracy: 10.5%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 17, loss: 2.302585, accuracy: 11.3%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 18, loss: 2.302585, accuracy: 8.2%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 19, loss: 2.302585, accuracy: 7.0%
# Accuracy: 10.2%, Avg loss: 2.302585
#
# batch 20, loss: 2.302585, accuracy: 10.2%
# Accuracy: 10.2%, Avg loss: 2.302633
#
# batch 21, loss: 2.301311, accuracy: 8.6%
# Accuracy: 10.3%, Avg loss: 2.302573
#
# batch 22, loss: 2.302817, accuracy: 10.2%
# Accuracy: 10.3%, Avg loss: 2.302661
#
# batch 23, loss: 2.302586, accuracy: 7.1%
# Accuracy: 10.3%, Avg loss: 2.302608
#
# Epoch 3
# -------------------------------
# batch 0, loss: 2.302406, accuracy: 10.2%
# Accuracy: 10.4%, Avg loss: 2.302412
#
# batch 1, loss: 2.303207, accuracy: 10.9%
# Accuracy: 10.5%, Avg loss: 2.302454
#
# batch 2, loss: 2.302330, accuracy: 14.1%
# Accuracy: 10.7%, Avg loss: 2.302401
#
# batch 3, loss: 2.301241, accuracy: 11.3%
# Accuracy: 10.8%, Avg loss: 2.302348
#
# batch 4, loss: 2.302632, accuracy: 8.2%
# Accuracy: 11.0%, Avg loss: 2.301930
#
# batch 5, loss: 2.303869, accuracy: 10.9%
# Accuracy: 11.1%, Avg loss: 2.301415
#
# batch 6, loss: 2.302316, accuracy: 9.4%
# Accuracy: 11.0%, Avg loss: 2.301211
#
# batch 7, loss: 2.299605, accuracy: 11.3%
# Accuracy: 11.2%, Avg loss: 2.300442
#
# batch 8, loss: 2.300775, accuracy: 10.9%
# Accuracy: 11.2%, Avg loss: 2.299891
#
# batch 9, loss: 2.297916, accuracy: 10.2%
# Accuracy: 11.2%, Avg loss: 2.299583
#
# batch 10, loss: 2.300422, accuracy: 9.0%
# Accuracy: 12.2%, Avg loss: 2.298568
#
# batch 11, loss: 2.300189, accuracy: 12.5%
# Accuracy: 12.2%, Avg loss: 2.297716
#
# batch 12, loss: 2.298364, accuracy: 13.3%
# Accuracy: 12.4%, Avg loss: 2.296983
#
# batch 13, loss: 2.292823, accuracy: 9.8%
# Accuracy: 12.2%, Avg loss: 2.293530
#
# batch 14, loss: 2.285736, accuracy: 16.4%
# Accuracy: 14.1%, Avg loss: 2.291608
#
# batch 15, loss: 2.274727, accuracy: 17.2%
# Accuracy: 14.1%, Avg loss: 2.288880
#
# batch 16, loss: 2.282098, accuracy: 12.5%
# Accuracy: 14.3%, Avg loss: 2.285289
#
# batch 17, loss: 2.285834, accuracy: 11.7%
# Accuracy: 15.3%, Avg loss: 2.281126
#
# batch 18, loss: 2.259779, accuracy: 17.6%
# Accuracy: 15.2%, Avg loss: 2.278704
#
# batch 19, loss: 2.273897, accuracy: 18.8%
# Accuracy: 15.5%, Avg loss: 2.277864
#
# batch 20, loss: 2.282595, accuracy: 16.4%
# Accuracy: 17.4%, Avg loss: 2.274597
#
# batch 21, loss: 2.266383, accuracy: 19.5%
# Accuracy: 17.8%, Avg loss: 2.271968
#
# batch 22, loss: 2.254399, accuracy: 19.9%
# Accuracy: 17.9%, Avg loss: 2.267015
#
# batch 23, loss: 2.250362, accuracy: 20.5%
# Accuracy: 18.0%, Avg loss: 2.264411
#
# Epoch 4
# -------------------------------
# batch 0, loss: 2.218594, accuracy: 19.5%
# Accuracy: 19.1%, Avg loss: 2.255461
#
# batch 1, loss: 2.213512, accuracy: 23.8%
# Accuracy: 19.1%, Avg loss: 2.249925
#
# batch 2, loss: 2.211464, accuracy: 21.1%
# Accuracy: 19.9%, Avg loss: 2.244357
#
# batch 3, loss: 2.239739, accuracy: 19.1%
# Accuracy: 21.1%, Avg loss: 2.236356
#
# batch 4, loss: 2.214286, accuracy: 23.4%
# Accuracy: 21.1%, Avg loss: 2.230195
#
# batch 5, loss: 2.191572, accuracy: 25.8%
# Accuracy: 21.0%, Avg loss: 2.224083
#
# batch 6, loss: 2.218953, accuracy: 19.9%
# Accuracy: 21.6%, Avg loss: 2.216576
#
# batch 7, loss: 2.146303, accuracy: 27.7%
# Accuracy: 23.1%, Avg loss: 2.211236
#
# batch 8, loss: 2.152455, accuracy: 28.9%
# Accuracy: 23.8%, Avg loss: 2.201642
#
# batch 9, loss: 2.189074, accuracy: 23.4%
# Accuracy: 24.6%, Avg loss: 2.192326
#
# batch 10, loss: 2.182118, accuracy: 21.5%
# Accuracy: 25.9%, Avg loss: 2.182167
#
# batch 11, loss: 2.082819, accuracy: 32.8%
# Accuracy: 26.5%, Avg loss: 2.168074
#
# batch 12, loss: 2.141469, accuracy: 27.7%
# Accuracy: 27.4%, Avg loss: 2.157505
#
# batch 13, loss: 2.126824, accuracy: 27.0%
# Accuracy: 27.8%, Avg loss: 2.141806
#
# batch 14, loss: 2.123987, accuracy: 30.9%
# Accuracy: 28.0%, Avg loss: 2.124141
#
# batch 15, loss: 2.091550, accuracy: 30.9%
# Accuracy: 28.6%, Avg loss: 2.100925
#
# batch 16, loss: 2.023627, accuracy: 30.9%
# Accuracy: 29.1%, Avg loss: 2.087156
#
# batch 17, loss: 2.031783, accuracy: 32.4%
# Accuracy: 29.3%, Avg loss: 2.071379
#
# batch 18, loss: 2.027231, accuracy: 29.3%
# Accuracy: 31.2%, Avg loss: 2.052402
#
# batch 19, loss: 2.046325, accuracy: 30.1%
# Accuracy: 31.6%, Avg loss: 2.033082
#
# batch 20, loss: 2.012963, accuracy: 37.1%
# Accuracy: 32.4%, Avg loss: 2.008449
#
# batch 21, loss: 1.947322, accuracy: 37.5%
# Accuracy: 34.2%, Avg loss: 1.985951
#
# batch 22, loss: 1.968135, accuracy: 32.0%
# Accuracy: 35.0%, Avg loss: 1.960754
#
# batch 23, loss: 1.915890, accuracy: 37.5%
# Accuracy: 36.7%, Avg loss: 1.933990
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆█████████</td></tr><tr><td>epoch_val_acc</td><td>▁▁▁▃█</td></tr><tr><td>epoch_val_average_neuron_spikes</td><td>▁▁▁▂█</td></tr><tr><td>epoch_val_loss</td><td>███▇▁</td></tr><tr><td>epoch_val_spike_percentage</td><td>▁▁▁▂█</td></tr><tr><td>train_acc</td><td>▂▁▂▁▂▃▁▁▂▁▂▁▂▁▂▃▂▂▂▁▂▂▂▂▁▂▁▂▃▁▂▁▄▄▂▅▅▇▆█</td></tr><tr><td>train_average_neuron_spikes</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▄▅▆▆█</td></tr><tr><td>train_loss</td><td>███████████████████████████████▇█▆▆▅▃▃▂▁</td></tr><tr><td>train_spike_percentage</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▄▄▆█</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▄▅▅▆█</td></tr><tr><td>val_average_neuron_spikes</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▅▆█</td></tr><tr><td>val_loss</td><td>█████████████████████████████████▇▇▆▆▅▄▁</td></tr><tr><td>val_spike_percentage</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▃▄▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>epoch_val_acc</td><td>0.367</td></tr><tr><td>epoch_val_average_neuron_spikes</td><td>0.11569</td></tr><tr><td>epoch_val_loss</td><td>1.93399</td></tr><tr><td>epoch_val_spike_percentage</td><td>0.11462</td></tr><tr><td>train_acc</td><td>0.375</td></tr><tr><td>train_average_neuron_spikes</td><td>0.12545</td></tr><tr><td>train_loss</td><td>1.91589</td></tr><tr><td>train_spike_percentage</td><td>0.12402</td></tr><tr><td>val_acc</td><td>0.367</td></tr><tr><td>val_average_neuron_spikes</td><td>0.11569</td></tr><tr><td>val_loss</td><td>1.93399</td></tr><tr><td>val_spike_percentage</td><td>0.11462</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">256-loss_fn_spk-0.01-SGD-10-100-0.1</strong> at: <a href='https://wandb.ai/DarwinNeuron/Test/runs/k61yczh9' target="_blank">https://wandb.ai/DarwinNeuron/Test/runs/k61yczh9</a><br> View project at: <a href='https://wandb.ai/DarwinNeuron/Test' target="_blank">https://wandb.ai/DarwinNeuron/Test</a><br>Synced 5 W&B file(s), 0 media file(s), 250 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250813_164437-k61yczh9\logs</code>
